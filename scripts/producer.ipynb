# %%
from kafka import KafkaProducer
import json
import time
import random

producer = KafkaProducer(
    bootstrap_servers='localhost:9092',
    value_serializer=lambda v: json.dumps(v).encode('utf-8')
)

flights_info = {
    "FL1000": {"origin": (40.6413, -73.7781), "destination": (51.4700, -0.4543)},  # JFK -> LHR
    "FL1001": {"origin": (34.0522, -118.2437), "destination": (48.8566, 2.3522)},  # LAX -> CDG
    "FL1002": {"origin": (25.2048, 55.2708), "destination": (1.3521, 103.8198)},   # DXB -> SIN
    "FL1003": {"origin": (35.6895, 139.6917), "destination": (37.7749, -122.4194)},# Tokyo -> San Francisco
    "FL1004": {"origin": (55.7558, 37.6173), "destination": (41.9028, 12.4964)},    # Moscow -> Rome
    "FL1005": {"origin": (39.9042, 116.4074), "destination": (19.0760, 72.8777)},   # Beijing -> Mumbai
    "FL1006": {"origin": (52.5200, 13.4050), "destination": (40.7128, -74.0060)},   # Berlin -> New York
    "FL1007": {"origin": (51.5074, -0.1278), "destination": (35.6895, 139.6917)},   # London -> Tokyo
}


statuses_progression = ["On Time", "Delayed", "Boarding", "In Air", "Arrived"]

flights_state = {}
for flight_id, info in flights_info.items():
    flights_state[flight_id] = {
        "status": "On Time",
        "departure_time": int(time.time()),
        "arrival_time": int(time.time()) + random.randint(3600, 7200)
    }

while True:
    flight_id = random.choice(list(flights_info.keys()))
    state = flights_state[flight_id]

    current_status = state["status"]
    if current_status != "Arrived":
        next_status = random.choice(statuses_progression)
    else:
        next_status = "Arrived"

    state["status"] = next_status
    state["arrival_time"] += random.randint(-600, 900)  # +/- 5-10 mins

    flight = {
        "flight_id": flight_id,
        "origin": flights_info[flight_id]["origin"],
        "destination": flights_info[flight_id]["destination"],
        "status": state["status"],
        "departure_time": state["departure_time"],
        "arrival_time": state["arrival_time"]
    }

    producer.send("flights", flight)
    print(f"Produced: {flight}")
    time.sleep(3)
# Out:
# Produced: {'flight_id': 'FL1002', 'origin': (25.2048, 55.2708), 'destination': (1.3521, 103.8198), 'status': 'In Air', 'departure_time': 1759171711, 'arrival_time': 1759178249}
# Produced: {'flight_id': 'FL1000', 'origin': (40.6413, -73.7781), 'destination': (51.47, -0.4543), 'status': 'Delayed', 'departure_time': 1759171711, 'arrival_time': 1759176535}
# Produced: {'flight_id': 'FL1001', 'origin': (34.0522, -118.2437), 'destination': (48.8566, 2.3522), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759178436}
# Produced: {'flight_id': 'FL1000', 'origin': (40.6413, -73.7781), 'destination': (51.47, -0.4543), 'status': 'On Time', 'departure_time': 1759171711, 'arrival_time': 1759176462}
# Produced: {'flight_id': 'FL1000', 'origin': (40.6413, -73.7781), 'destination': (51.47, -0.4543), 'status': 'In Air', 'departure_time': 1759171711, 'arrival_time': 1759176633}
# Produced: {'flight_id': 'FL1005', 'origin': (39.9042, 116.4074), 'destination': (19.076, 72.8777), 'status': 'On Time', 'departure_time': 1759171711, 'arrival_time': 1759177772}
# Produced: {'flight_id': 'FL1001', 'origin': (34.0522, -118.2437), 'destination': (48.8566, 2.3522), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759178867}
# Produced: {'flight_id': 'FL1003', 'origin': (35.6895, 139.6917), 'destination': (37.7749, -122.4194), 'status': 'On Time', 'departure_time': 1759171711, 'arrival_time': 1759175556}
# Produced: {'flight_id': 'FL1005', 'origin': (39.9042, 116.4074), 'destination': (19.076, 72.8777), 'status': 'Boarding', 'departure_time': 1759171711, 'arrival_time': 1759178182}
# Produced: {'flight_id': 'FL1006', 'origin': (52.52, 13.405), 'destination': (40.7128, -74.006), 'status': 'On Time', 'departure_time': 1759171711, 'arrival_time': 1759178767}
# Produced: {'flight_id': 'FL1005', 'origin': (39.9042, 116.4074), 'destination': (19.076, 72.8777), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759178265}
# Produced: {'flight_id': 'FL1007', 'origin': (51.5074, -0.1278), 'destination': (35.6895, 139.6917), 'status': 'In Air', 'departure_time': 1759171711, 'arrival_time': 1759177962}
# Produced: {'flight_id': 'FL1001', 'origin': (34.0522, -118.2437), 'destination': (48.8566, 2.3522), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759178803}
# Produced: {'flight_id': 'FL1000', 'origin': (40.6413, -73.7781), 'destination': (51.47, -0.4543), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759176761}
# Produced: {'flight_id': 'FL1006', 'origin': (52.52, 13.405), 'destination': (40.7128, -74.006), 'status': 'Boarding', 'departure_time': 1759171711, 'arrival_time': 1759178569}
# Produced: {'flight_id': 'FL1006', 'origin': (52.52, 13.405), 'destination': (40.7128, -74.006), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759178931}
# Produced: {'flight_id': 'FL1007', 'origin': (51.5074, -0.1278), 'destination': (35.6895, 139.6917), 'status': 'In Air', 'departure_time': 1759171711, 'arrival_time': 1759178510}
# Produced: {'flight_id': 'FL1000', 'origin': (40.6413, -73.7781), 'destination': (51.47, -0.4543), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759176778}
# Produced: {'flight_id': 'FL1006', 'origin': (52.52, 13.405), 'destination': (40.7128, -74.006), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759178959}
# Produced: {'flight_id': 'FL1007', 'origin': (51.5074, -0.1278), 'destination': (35.6895, 139.6917), 'status': 'In Air', 'departure_time': 1759171711, 'arrival_time': 1759179077}
# Produced: {'flight_id': 'FL1006', 'origin': (52.52, 13.405), 'destination': (40.7128, -74.006), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759179233}
# Produced: {'flight_id': 'FL1004', 'origin': (55.7558, 37.6173), 'destination': (41.9028, 12.4964), 'status': 'In Air', 'departure_time': 1759171711, 'arrival_time': 1759175471}
# Produced: {'flight_id': 'FL1002', 'origin': (25.2048, 55.2708), 'destination': (1.3521, 103.8198), 'status': 'In Air', 'departure_time': 1759171711, 'arrival_time': 1759178297}
# Produced: {'flight_id': 'FL1004', 'origin': (55.7558, 37.6173), 'destination': (41.9028, 12.4964), 'status': 'Delayed', 'departure_time': 1759171711, 'arrival_time': 1759175541}
# Produced: {'flight_id': 'FL1004', 'origin': (55.7558, 37.6173), 'destination': (41.9028, 12.4964), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759175282}
# Produced: {'flight_id': 'FL1007', 'origin': (51.5074, -0.1278), 'destination': (35.6895, 139.6917), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759179494}
# Produced: {'flight_id': 'FL1002', 'origin': (25.2048, 55.2708), 'destination': (1.3521, 103.8198), 'status': 'On Time', 'departure_time': 1759171711, 'arrival_time': 1759178722}
# Produced: {'flight_id': 'FL1002', 'origin': (25.2048, 55.2708), 'destination': (1.3521, 103.8198), 'status': 'Boarding', 'departure_time': 1759171711, 'arrival_time': 1759179293}
# Produced: {'flight_id': 'FL1002', 'origin': (25.2048, 55.2708), 'destination': (1.3521, 103.8198), 'status': 'In Air', 'departure_time': 1759171711, 'arrival_time': 1759179545}
# Produced: {'flight_id': 'FL1000', 'origin': (40.6413, -73.7781), 'destination': (51.47, -0.4543), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759176652}
# Produced: {'flight_id': 'FL1002', 'origin': (25.2048, 55.2708), 'destination': (1.3521, 103.8198), 'status': 'In Air', 'departure_time': 1759171711, 'arrival_time': 1759179540}
# Produced: {'flight_id': 'FL1005', 'origin': (39.9042, 116.4074), 'destination': (19.076, 72.8777), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759178508}
# Produced: {'flight_id': 'FL1004', 'origin': (55.7558, 37.6173), 'destination': (41.9028, 12.4964), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759175711}
# Produced: {'flight_id': 'FL1003', 'origin': (35.6895, 139.6917), 'destination': (37.7749, -122.4194), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759175897}
# Produced: {'flight_id': 'FL1007', 'origin': (51.5074, -0.1278), 'destination': (35.6895, 139.6917), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759179515}
# Produced: {'flight_id': 'FL1005', 'origin': (39.9042, 116.4074), 'destination': (19.076, 72.8777), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759178613}
# Produced: {'flight_id': 'FL1004', 'origin': (55.7558, 37.6173), 'destination': (41.9028, 12.4964), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759175703}
# Produced: {'flight_id': 'FL1005', 'origin': (39.9042, 116.4074), 'destination': (19.076, 72.8777), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759178721}
# Produced: {'flight_id': 'FL1004', 'origin': (55.7558, 37.6173), 'destination': (41.9028, 12.4964), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759176242}
# Produced: {'flight_id': 'FL1006', 'origin': (52.52, 13.405), 'destination': (40.7128, -74.006), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759179010}
# Produced: {'flight_id': 'FL1000', 'origin': (40.6413, -73.7781), 'destination': (51.47, -0.4543), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759176389}
# Produced: {'flight_id': 'FL1007', 'origin': (51.5074, -0.1278), 'destination': (35.6895, 139.6917), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759179907}
# Produced: {'flight_id': 'FL1006', 'origin': (52.52, 13.405), 'destination': (40.7128, -74.006), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759179562}
# Produced: {'flight_id': 'FL1006', 'origin': (52.52, 13.405), 'destination': (40.7128, -74.006), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759180131}
# Produced: {'flight_id': 'FL1001', 'origin': (34.0522, -118.2437), 'destination': (48.8566, 2.3522), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759179188}
# Produced: {'flight_id': 'FL1000', 'origin': (40.6413, -73.7781), 'destination': (51.47, -0.4543), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759176702}
# Produced: {'flight_id': 'FL1005', 'origin': (39.9042, 116.4074), 'destination': (19.076, 72.8777), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759178443}
# Produced: {'flight_id': 'FL1001', 'origin': (34.0522, -118.2437), 'destination': (48.8566, 2.3522), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759179768}
# Produced: {'flight_id': 'FL1004', 'origin': (55.7558, 37.6173), 'destination': (41.9028, 12.4964), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759175971}
# Produced: {'flight_id': 'FL1006', 'origin': (52.52, 13.405), 'destination': (40.7128, -74.006), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759180387}
# Produced: {'flight_id': 'FL1007', 'origin': (51.5074, -0.1278), 'destination': (35.6895, 139.6917), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759179977}
# Produced: {'flight_id': 'FL1003', 'origin': (35.6895, 139.6917), 'destination': (37.7749, -122.4194), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759176131}
# Produced: {'flight_id': 'FL1004', 'origin': (55.7558, 37.6173), 'destination': (41.9028, 12.4964), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759176523}
# Produced: {'flight_id': 'FL1007', 'origin': (51.5074, -0.1278), 'destination': (35.6895, 139.6917), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759180122}
# Produced: {'flight_id': 'FL1007', 'origin': (51.5074, -0.1278), 'destination': (35.6895, 139.6917), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759180110}
# Produced: {'flight_id': 'FL1003', 'origin': (35.6895, 139.6917), 'destination': (37.7749, -122.4194), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759176562}
# Produced: {'flight_id': 'FL1007', 'origin': (51.5074, -0.1278), 'destination': (35.6895, 139.6917), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759180649}
# Produced: {'flight_id': 'FL1007', 'origin': (51.5074, -0.1278), 'destination': (35.6895, 139.6917), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759180572}
# Produced: {'flight_id': 'FL1000', 'origin': (40.6413, -73.7781), 'destination': (51.47, -0.4543), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759176819}
# Produced: {'flight_id': 'FL1003', 'origin': (35.6895, 139.6917), 'destination': (37.7749, -122.4194), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759176772}
# Produced: {'flight_id': 'FL1002', 'origin': (25.2048, 55.2708), 'destination': (1.3521, 103.8198), 'status': 'In Air', 'departure_time': 1759171711, 'arrival_time': 1759179344}
# Produced: {'flight_id': 'FL1007', 'origin': (51.5074, -0.1278), 'destination': (35.6895, 139.6917), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759180694}
# Produced: {'flight_id': 'FL1001', 'origin': (34.0522, -118.2437), 'destination': (48.8566, 2.3522), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759179894}
# Produced: {'flight_id': 'FL1003', 'origin': (35.6895, 139.6917), 'destination': (37.7749, -122.4194), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759176543}
# Produced: {'flight_id': 'FL1007', 'origin': (51.5074, -0.1278), 'destination': (35.6895, 139.6917), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759181080}
# Produced: {'flight_id': 'FL1000', 'origin': (40.6413, -73.7781), 'destination': (51.47, -0.4543), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759176609}
# Produced: {'flight_id': 'FL1002', 'origin': (25.2048, 55.2708), 'destination': (1.3521, 103.8198), 'status': 'Delayed', 'departure_time': 1759171711, 'arrival_time': 1759179776}
# Produced: {'flight_id': 'FL1007', 'origin': (51.5074, -0.1278), 'destination': (35.6895, 139.6917), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759181370}
# Produced: {'flight_id': 'FL1002', 'origin': (25.2048, 55.2708), 'destination': (1.3521, 103.8198), 'status': 'Boarding', 'departure_time': 1759171711, 'arrival_time': 1759180257}
# Produced: {'flight_id': 'FL1003', 'origin': (35.6895, 139.6917), 'destination': (37.7749, -122.4194), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759177096}
# Produced: {'flight_id': 'FL1004', 'origin': (55.7558, 37.6173), 'destination': (41.9028, 12.4964), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759176232}
# Produced: {'flight_id': 'FL1005', 'origin': (39.9042, 116.4074), 'destination': (19.076, 72.8777), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759178694}
# Produced: {'flight_id': 'FL1006', 'origin': (52.52, 13.405), 'destination': (40.7128, -74.006), 'status': 'Arrived', 'departure_time': 1759171711, 'arrival_time': 1759180887}
# Produced: {'flight_id': 'FL1002', 'origin': (25.2048, 55.2708), 'destination': (1.3521, 103.8198), 'status': 'Delayed', 'departure_time': 1759171711, 'arrival_time': 1759180278}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-ceb102e1a631> in <module>
#      55     producer.send("flights1", flight)
#      56     print(f"Produced: {flight}")
# ---> 57     time.sleep(3)
#      58
#
# KeyboardInterrupt:
